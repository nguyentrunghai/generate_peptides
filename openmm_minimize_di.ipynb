# %%
from sys import stdout
import time
import os

from simtk.openmm.app import PDBFile, PDBReporter
from simtk.openmm.app import ForceField, HBonds
from simtk.openmm import LangevinIntegrator

from simtk.unit import nanometer, kelvin, picosecond, femtoseconds

from simtk.openmm.app import Simulation

# %%
def minimize(pdb_inp, pdb_out):
    t0 = time.time()
    pdb = PDBFile(pdb_inp)
    print(pdb.topology)
    forcefield = ForceField('amber14-all.xml')
    system = forcefield.createSystem(pdb.topology, nonbondedCutoff=3*nanometer, constraints=HBonds)
    integrator = LangevinIntegrator(300*kelvin, 1/picosecond, 2*femtoseconds)
    simulation = Simulation(pdb.topology, system, integrator)
    simulation.context.setPositions(pdb.positions)
    simulation.minimizeEnergy(maxIterations=100)
    
    pos = simulation.context.getState(getPositions=True)
    PDBFile.writeFile(pdb.topology, pos.getPositions(), open(pdb_out, "w"))
    print("Time: %0.5f s\n" % (time.time() - t0))
    return None

# %%
INP_DIR = "add_Hydrogens/dipeptides"
OUT_DIR = "minimize/dipeptides"

AA_LIST = "ACDEFGHIKLMNPQRSTVWY"

# %%
for aa1 in AA_LIST:
    for aa2 in AA_LIST:
        pdb_inp = os.path.join(INP_DIR, aa1+aa2+".pdb")
        pdb_out = os.path.join(OUT_DIR, aa1+aa2+".pdb")
        print(pdb_inp)

        minimize(pdb_inp, pdb_out)
# Out:
# add_Hydrogens/dipeptides/AA.pdb
# <Topology; 1 chains, 2 residues, 23 atoms, 22 bonds>
# Time: 1.89201 s
#
# add_Hydrogens/dipeptides/AC.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 23 bonds>
# Time: 1.17954 s
#
# add_Hydrogens/dipeptides/AD.pdb
# <Topology; 1 chains, 2 residues, 25 atoms, 24 bonds>
# Time: 1.55444 s
#
# add_Hydrogens/dipeptides/AE.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 1.17790 s
#
# add_Hydrogens/dipeptides/AF.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 33 bonds>
# Time: 1.20839 s
#
# add_Hydrogens/dipeptides/AG.pdb
# <Topology; 1 chains, 2 residues, 20 atoms, 19 bonds>
# Time: 1.55205 s
#
# add_Hydrogens/dipeptides/AH.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 30 bonds>
# Time: 1.18778 s
#
# add_Hydrogens/dipeptides/AI.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 1.20277 s
#
# add_Hydrogens/dipeptides/AK.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 34 bonds>
# Time: 1.19090 s
#
# add_Hydrogens/dipeptides/AL.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.72141 s
#
# add_Hydrogens/dipeptides/AM.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 1.09996 s
#
# add_Hydrogens/dipeptides/AN.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 26 bonds>
# Time: 0.86815 s
#
# add_Hydrogens/dipeptides/AP.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 27 bonds>
# Time: 1.09108 s
#
# add_Hydrogens/dipeptides/AQ.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 0.78311 s
#
# add_Hydrogens/dipeptides/AR.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 1.19169 s
#
# add_Hydrogens/dipeptides/AS.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 23 bonds>
# Time: 0.67043 s
#
# add_Hydrogens/dipeptides/AT.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 26 bonds>
# Time: 1.08407 s
#
# add_Hydrogens/dipeptides/AV.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 1.18850 s
#
# add_Hydrogens/dipeptides/AW.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 38 bonds>
# Time: 1.13232 s
#
# add_Hydrogens/dipeptides/AY.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 1.18746 s
#
# add_Hydrogens/dipeptides/CA.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 23 bonds>
# Time: 0.28964 s
#
# add_Hydrogens/dipeptides/CC.pdb
# <Topology; 1 chains, 2 residues, 25 atoms, 24 bonds>
# Time: 1.12336 s
#
# add_Hydrogens/dipeptides/CD.pdb
# <Topology; 1 chains, 2 residues, 26 atoms, 25 bonds>
# Time: 1.54689 s
#
# add_Hydrogens/dipeptides/CE.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 1.10501 s
#
# add_Hydrogens/dipeptides/CF.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 1.09441 s
#
# add_Hydrogens/dipeptides/CG.pdb
# <Topology; 1 chains, 2 residues, 21 atoms, 20 bonds>
# Time: 1.54095 s
#
# add_Hydrogens/dipeptides/CH.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 1.18184 s
#
# add_Hydrogens/dipeptides/CI.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 1.09755 s
#
# add_Hydrogens/dipeptides/CK.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 1.17423 s
#
# add_Hydrogens/dipeptides/CL.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.70719 s
#
# add_Hydrogens/dipeptides/CM.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 1.08172 s
#
# add_Hydrogens/dipeptides/CN.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 0.77644 s
#
# add_Hydrogens/dipeptides/CP.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 28 bonds>
# Time: 1.10413 s
#
# add_Hydrogens/dipeptides/CQ.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.76548 s
#
# add_Hydrogens/dipeptides/CR.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 37 bonds>
# Time: 1.09134 s
#
# add_Hydrogens/dipeptides/CS.pdb
# <Topology; 1 chains, 2 residues, 25 atoms, 24 bonds>
# Time: 0.65572 s
#
# add_Hydrogens/dipeptides/CT.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 1.10017 s
#
# add_Hydrogens/dipeptides/CV.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 0.72170 s
#
# add_Hydrogens/dipeptides/CW.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 39 bonds>
# Time: 1.13165 s
#
# add_Hydrogens/dipeptides/CY.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 35 bonds>
# Time: 1.10470 s
#
# add_Hydrogens/dipeptides/DA.pdb
# <Topology; 1 chains, 2 residues, 25 atoms, 24 bonds>
# Time: 0.29638 s
#
# add_Hydrogens/dipeptides/DC.pdb
# <Topology; 1 chains, 2 residues, 26 atoms, 25 bonds>
# Time: 0.29592 s
#
# add_Hydrogens/dipeptides/DD.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 26 bonds>
# Time: 1.11673 s
#
# add_Hydrogens/dipeptides/DE.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 1.10132 s
#
# add_Hydrogens/dipeptides/DF.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 35 bonds>
# Time: 1.10010 s
#
# add_Hydrogens/dipeptides/DG.pdb
# <Topology; 1 chains, 2 residues, 22 atoms, 21 bonds>
# Time: 1.55048 s
#
# add_Hydrogens/dipeptides/DH.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 32 bonds>
# Time: 1.10577 s
#
# add_Hydrogens/dipeptides/DI.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 1.11037 s
#
# add_Hydrogens/dipeptides/DK.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 0.77539 s
#
# add_Hydrogens/dipeptides/DL.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.71573 s
#
# add_Hydrogens/dipeptides/DM.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 1.10290 s
#
# add_Hydrogens/dipeptides/DN.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.78782 s
#
# add_Hydrogens/dipeptides/DP.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 29 bonds>
# Time: 1.09592 s
#
# add_Hydrogens/dipeptides/DQ.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.79700 s
#
# add_Hydrogens/dipeptides/DR.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 1.11744 s
#
# add_Hydrogens/dipeptides/DS.pdb
# <Topology; 1 chains, 2 residues, 26 atoms, 25 bonds>
# Time: 0.66478 s
#
# add_Hydrogens/dipeptides/DT.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 1.13419 s
#
# add_Hydrogens/dipeptides/DV.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 1.08835 s
#
# add_Hydrogens/dipeptides/DW.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 40 bonds>
# Time: 1.09238 s
#
# add_Hydrogens/dipeptides/DY.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 36 bonds>
# Time: 1.09450 s
#
# add_Hydrogens/dipeptides/EA.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 0.31803 s
#
# add_Hydrogens/dipeptides/EC.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.29661 s
#
# add_Hydrogens/dipeptides/ED.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 0.28321 s
#
# add_Hydrogens/dipeptides/EE.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 1.08502 s
#
# add_Hydrogens/dipeptides/EF.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 38 bonds>
# Time: 1.12375 s
#
# add_Hydrogens/dipeptides/EG.pdb
# <Topology; 1 chains, 2 residues, 25 atoms, 24 bonds>
# Time: 0.28048 s
#
# add_Hydrogens/dipeptides/EH.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 35 bonds>
# Time: 1.08602 s
#
# add_Hydrogens/dipeptides/EI.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 1.08661 s
#
# add_Hydrogens/dipeptides/EK.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 39 bonds>
# Time: 0.85629 s
#
# add_Hydrogens/dipeptides/EL.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 0.72333 s
#
# add_Hydrogens/dipeptides/EM.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 34 bonds>
# Time: 1.11457 s
#
# add_Hydrogens/dipeptides/EN.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.30888 s
#
# add_Hydrogens/dipeptides/EP.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 32 bonds>
# Time: 1.09806 s
#
# add_Hydrogens/dipeptides/EQ.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 34 bonds>
# Time: 0.77602 s
#
# add_Hydrogens/dipeptides/ER.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 41 bonds>
# Time: 1.10956 s
#
# add_Hydrogens/dipeptides/ES.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.29683 s
#
# add_Hydrogens/dipeptides/ET.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 1.11921 s
#
# add_Hydrogens/dipeptides/EV.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.72101 s
#
# add_Hydrogens/dipeptides/EW.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 43 bonds>
# Time: 1.10371 s
#
# add_Hydrogens/dipeptides/EY.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 1.09032 s
#
# add_Hydrogens/dipeptides/FA.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 33 bonds>
# Time: 0.29578 s
#
# add_Hydrogens/dipeptides/FC.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.29505 s
#
# add_Hydrogens/dipeptides/FD.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 35 bonds>
# Time: 0.30178 s
#
# add_Hydrogens/dipeptides/FE.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 38 bonds>
# Time: 0.29599 s
#
# add_Hydrogens/dipeptides/FF.pdb
# <Topology; 1 chains, 2 residues, 43 atoms, 44 bonds>
# Time: 1.09740 s
#
# add_Hydrogens/dipeptides/FG.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 30 bonds>
# Time: 1.09761 s
#
# add_Hydrogens/dipeptides/FH.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 41 bonds>
# Time: 1.09557 s
#
# add_Hydrogens/dipeptides/FI.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 42 bonds>
# Time: 1.09726 s
#
# add_Hydrogens/dipeptides/FK.pdb
# <Topology; 1 chains, 2 residues, 45 atoms, 45 bonds>
# Time: 1.08973 s
#
# add_Hydrogens/dipeptides/FL.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 42 bonds>
# Time: 0.70994 s
#
# add_Hydrogens/dipeptides/FM.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 40 bonds>
# Time: 1.09894 s
#
# add_Hydrogens/dipeptides/FN.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 37 bonds>
# Time: 0.77257 s
#
# add_Hydrogens/dipeptides/FP.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 38 bonds>
# Time: 1.09697 s
#
# add_Hydrogens/dipeptides/FQ.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 40 bonds>
# Time: 0.77634 s
#
# add_Hydrogens/dipeptides/FR.pdb
# <Topology; 1 chains, 2 residues, 47 atoms, 47 bonds>
# Time: 1.09745 s
#
# add_Hydrogens/dipeptides/FS.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.28445 s
#
# add_Hydrogens/dipeptides/FT.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 37 bonds>
# Time: 1.09951 s
#
# add_Hydrogens/dipeptides/FV.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 1.13871 s
#
# add_Hydrogens/dipeptides/FW.pdb
# <Topology; 1 chains, 2 residues, 47 atoms, 49 bonds>
# Time: 1.10076 s
#
# add_Hydrogens/dipeptides/FY.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 45 bonds>
# Time: 1.09063 s
#
# add_Hydrogens/dipeptides/GA.pdb
# <Topology; 1 chains, 2 residues, 20 atoms, 19 bonds>
# Time: 0.28231 s
#
# add_Hydrogens/dipeptides/GC.pdb
# <Topology; 1 chains, 2 residues, 21 atoms, 20 bonds>
# Time: 0.31599 s
#
# add_Hydrogens/dipeptides/GD.pdb
# <Topology; 1 chains, 2 residues, 22 atoms, 21 bonds>
# Time: 0.28040 s
#
# add_Hydrogens/dipeptides/GE.pdb
# <Topology; 1 chains, 2 residues, 25 atoms, 24 bonds>
# Time: 0.29123 s
#
# add_Hydrogens/dipeptides/GF.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 30 bonds>
# Time: 0.28255 s
#
# add_Hydrogens/dipeptides/GG.pdb
# <Topology; 1 chains, 2 residues, 17 atoms, 16 bonds>
# Time: 1.59683 s
#
# add_Hydrogens/dipeptides/GH.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 27 bonds>
# Time: 1.10086 s
#
# add_Hydrogens/dipeptides/GI.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.72310 s
#
# add_Hydrogens/dipeptides/GK.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 1.10626 s
#
# add_Hydrogens/dipeptides/GL.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.72719 s
#
# add_Hydrogens/dipeptides/GM.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 26 bonds>
# Time: 1.09633 s
#
# add_Hydrogens/dipeptides/GN.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 23 bonds>
# Time: 0.78426 s
#
# add_Hydrogens/dipeptides/GP.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 24 bonds>
# Time: 1.11483 s
#
# add_Hydrogens/dipeptides/GQ.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 26 bonds>
# Time: 0.28841 s
#
# add_Hydrogens/dipeptides/GR.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 1.10605 s
#
# add_Hydrogens/dipeptides/GS.pdb
# <Topology; 1 chains, 2 residues, 21 atoms, 20 bonds>
# Time: 0.67011 s
#
# add_Hydrogens/dipeptides/GT.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 23 bonds>
# Time: 0.71659 s
#
# add_Hydrogens/dipeptides/GV.pdb
# <Topology; 1 chains, 2 residues, 26 atoms, 25 bonds>
# Time: 1.10620 s
#
# add_Hydrogens/dipeptides/GW.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 35 bonds>
# Time: 1.09827 s
#
# add_Hydrogens/dipeptides/GY.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 1.10941 s
#
# add_Hydrogens/dipeptides/HA.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 30 bonds>
# Time: 0.28744 s
#
# add_Hydrogens/dipeptides/HC.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 0.29003 s
#
# add_Hydrogens/dipeptides/HD.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 32 bonds>
# Time: 0.28851 s
#
# add_Hydrogens/dipeptides/HE.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 35 bonds>
# Time: 0.29109 s
#
# add_Hydrogens/dipeptides/HF.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 41 bonds>
# Time: 0.29277 s
#
# add_Hydrogens/dipeptides/HG.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 27 bonds>
# Time: 0.28415 s
#
# add_Hydrogens/dipeptides/HH.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 38 bonds>
# Time: 1.12682 s
#
# add_Hydrogens/dipeptides/HI.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 1.10407 s
#
# add_Hydrogens/dipeptides/HK.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 42 bonds>
# Time: 1.08475 s
#
# add_Hydrogens/dipeptides/HL.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 0.70528 s
#
# add_Hydrogens/dipeptides/HM.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 37 bonds>
# Time: 1.09707 s
#
# add_Hydrogens/dipeptides/HN.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.76749 s
#
# add_Hydrogens/dipeptides/HP.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 35 bonds>
# Time: 1.08460 s
#
# add_Hydrogens/dipeptides/HQ.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 37 bonds>
# Time: 0.76211 s
#
# add_Hydrogens/dipeptides/HR.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 44 bonds>
# Time: 1.10477 s
#
# add_Hydrogens/dipeptides/HS.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 0.66261 s
#
# add_Hydrogens/dipeptides/HT.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 1.08887 s
#
# add_Hydrogens/dipeptides/HV.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 36 bonds>
# Time: 1.08653 s
#
# add_Hydrogens/dipeptides/HW.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 46 bonds>
# Time: 1.10846 s
#
# add_Hydrogens/dipeptides/HY.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 42 bonds>
# Time: 0.80511 s
#
# add_Hydrogens/dipeptides/IA.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.29629 s
#
# add_Hydrogens/dipeptides/IC.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.29320 s
#
# add_Hydrogens/dipeptides/ID.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.29953 s
#
# add_Hydrogens/dipeptides/IE.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 0.31025 s
#
# add_Hydrogens/dipeptides/IF.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 42 bonds>
# Time: 0.30213 s
#
# add_Hydrogens/dipeptides/IG.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.29809 s
#
# add_Hydrogens/dipeptides/IH.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 0.29145 s
#
# add_Hydrogens/dipeptides/II.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 1.10667 s
#
# add_Hydrogens/dipeptides/IK.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 43 bonds>
# Time: 1.09612 s
#
# add_Hydrogens/dipeptides/IL.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 0.71685 s
#
# add_Hydrogens/dipeptides/IM.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 1.11331 s
#
# add_Hydrogens/dipeptides/IN.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.78095 s
#
# add_Hydrogens/dipeptides/IP.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 36 bonds>
# Time: 1.09826 s
#
# add_Hydrogens/dipeptides/IQ.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.78595 s
#
# add_Hydrogens/dipeptides/IR.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 45 bonds>
# Time: 1.09145 s
#
# add_Hydrogens/dipeptides/IS.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.66644 s
#
# add_Hydrogens/dipeptides/IT.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 1.10398 s
#
# add_Hydrogens/dipeptides/IV.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 37 bonds>
# Time: 1.09501 s
#
# add_Hydrogens/dipeptides/IW.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 47 bonds>
# Time: 1.08813 s
#
# add_Hydrogens/dipeptides/IY.pdb
# <Topology; 1 chains, 2 residues, 43 atoms, 43 bonds>
# Time: 1.09213 s
#
# add_Hydrogens/dipeptides/KA.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 34 bonds>
# Time: 0.28519 s
#
# add_Hydrogens/dipeptides/KC.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.28622 s
#
# add_Hydrogens/dipeptides/KD.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 0.29322 s
#
# add_Hydrogens/dipeptides/KE.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 39 bonds>
# Time: 0.28942 s
#
# add_Hydrogens/dipeptides/KF.pdb
# <Topology; 1 chains, 2 residues, 45 atoms, 45 bonds>
# Time: 0.30408 s
#
# add_Hydrogens/dipeptides/KG.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.28235 s
#
# add_Hydrogens/dipeptides/KH.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 42 bonds>
# Time: 0.28189 s
#
# add_Hydrogens/dipeptides/KI.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 43 bonds>
# Time: 0.28656 s
#
# add_Hydrogens/dipeptides/KK.pdb
# <Topology; 1 chains, 2 residues, 47 atoms, 46 bonds>
# Time: 1.08929 s
#
# add_Hydrogens/dipeptides/KL.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 43 bonds>
# Time: 0.71984 s
#
# add_Hydrogens/dipeptides/KM.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 41 bonds>
# Time: 1.11120 s
#
# add_Hydrogens/dipeptides/KN.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.76770 s
#
# add_Hydrogens/dipeptides/KP.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 1.11911 s
#
# add_Hydrogens/dipeptides/KQ.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 41 bonds>
# Time: 0.77435 s
#
# add_Hydrogens/dipeptides/KR.pdb
# <Topology; 1 chains, 2 residues, 49 atoms, 48 bonds>
# Time: 1.09879 s
#
# add_Hydrogens/dipeptides/KS.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.66090 s
#
# add_Hydrogens/dipeptides/KT.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 1.10375 s
#
# add_Hydrogens/dipeptides/KV.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 1.10481 s
#
# add_Hydrogens/dipeptides/KW.pdb
# <Topology; 1 chains, 2 residues, 49 atoms, 50 bonds>
# Time: 1.11598 s
#
# add_Hydrogens/dipeptides/KY.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 46 bonds>
# Time: 1.10038 s
#
# add_Hydrogens/dipeptides/LA.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.30664 s
#
# add_Hydrogens/dipeptides/LC.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.29691 s
#
# add_Hydrogens/dipeptides/LD.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.28964 s
#
# add_Hydrogens/dipeptides/LE.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 0.30861 s
#
# add_Hydrogens/dipeptides/LF.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 42 bonds>
# Time: 0.29730 s
#
# add_Hydrogens/dipeptides/LG.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.28618 s
#
# add_Hydrogens/dipeptides/LH.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 0.30549 s
#
# add_Hydrogens/dipeptides/LI.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 0.28897 s
#
# add_Hydrogens/dipeptides/LK.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 43 bonds>
# Time: 0.29382 s
#
# add_Hydrogens/dipeptides/LL.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 0.71362 s
#
# add_Hydrogens/dipeptides/LM.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.72062 s
#
# add_Hydrogens/dipeptides/LN.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.72367 s
#
# add_Hydrogens/dipeptides/LP.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 36 bonds>
# Time: 0.72301 s
#
# add_Hydrogens/dipeptides/LQ.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.71826 s
#
# add_Hydrogens/dipeptides/LR.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 45 bonds>
# Time: 0.71997 s
#
# add_Hydrogens/dipeptides/LS.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.28569 s
#
# add_Hydrogens/dipeptides/LT.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.70898 s
#
# add_Hydrogens/dipeptides/LV.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 37 bonds>
# Time: 0.74369 s
#
# add_Hydrogens/dipeptides/LW.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 47 bonds>
# Time: 0.71846 s
#
# add_Hydrogens/dipeptides/LY.pdb
# <Topology; 1 chains, 2 residues, 43 atoms, 43 bonds>
# Time: 0.70568 s
#
# add_Hydrogens/dipeptides/MA.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 0.28652 s
#
# add_Hydrogens/dipeptides/MC.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.28410 s
#
# add_Hydrogens/dipeptides/MD.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.28080 s
#
# add_Hydrogens/dipeptides/ME.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 34 bonds>
# Time: 0.28563 s
#
# add_Hydrogens/dipeptides/MF.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 40 bonds>
# Time: 0.28552 s
#
# add_Hydrogens/dipeptides/MG.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 26 bonds>
# Time: 0.28563 s
#
# add_Hydrogens/dipeptides/MH.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 37 bonds>
# Time: 0.30373 s
#
# add_Hydrogens/dipeptides/MI.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.29285 s
#
# add_Hydrogens/dipeptides/MK.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 41 bonds>
# Time: 0.29352 s
#
# add_Hydrogens/dipeptides/ML.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.30088 s
#
# add_Hydrogens/dipeptides/MM.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 1.11219 s
#
# add_Hydrogens/dipeptides/MN.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.78807 s
#
# add_Hydrogens/dipeptides/MP.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 1.10737 s
#
# add_Hydrogens/dipeptides/MQ.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 0.79964 s
#
# add_Hydrogens/dipeptides/MR.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 43 bonds>
# Time: 1.09453 s
#
# add_Hydrogens/dipeptides/MS.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.66497 s
#
# add_Hydrogens/dipeptides/MT.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 1.10564 s
#
# add_Hydrogens/dipeptides/MV.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 1.09186 s
#
# add_Hydrogens/dipeptides/MW.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 45 bonds>
# Time: 1.09719 s
#
# add_Hydrogens/dipeptides/MY.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 41 bonds>
# Time: 1.09682 s
#
# add_Hydrogens/dipeptides/NA.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 26 bonds>
# Time: 0.28626 s
#
# add_Hydrogens/dipeptides/NC.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 0.28478 s
#
# add_Hydrogens/dipeptides/ND.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.28906 s
#
# add_Hydrogens/dipeptides/NE.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.28483 s
#
# add_Hydrogens/dipeptides/NF.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 37 bonds>
# Time: 0.28844 s
#
# add_Hydrogens/dipeptides/NG.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 23 bonds>
# Time: 0.28923 s
#
# add_Hydrogens/dipeptides/NH.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.28668 s
#
# add_Hydrogens/dipeptides/NI.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.28726 s
#
# add_Hydrogens/dipeptides/NK.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.28830 s
#
# add_Hydrogens/dipeptides/NL.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.28802 s
#
# add_Hydrogens/dipeptides/NM.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.28377 s
#
# add_Hydrogens/dipeptides/NN.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.77936 s
#
# add_Hydrogens/dipeptides/NP.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 0.77270 s
#
# add_Hydrogens/dipeptides/NQ.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.77096 s
#
# add_Hydrogens/dipeptides/NR.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 0.76579 s
#
# add_Hydrogens/dipeptides/NS.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 0.33918 s
#
# add_Hydrogens/dipeptides/NT.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.77020 s
#
# add_Hydrogens/dipeptides/NV.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.77738 s
#
# add_Hydrogens/dipeptides/NW.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 42 bonds>
# Time: 0.72796 s
#
# add_Hydrogens/dipeptides/NY.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 38 bonds>
# Time: 0.80286 s
#
# add_Hydrogens/dipeptides/PA.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 27 bonds>
# Time: 0.72941 s
#
# add_Hydrogens/dipeptides/PC.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 28 bonds>
# Time: 0.73000 s
#
# add_Hydrogens/dipeptides/PD.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 29 bonds>
# Time: 0.73085 s
#
# add_Hydrogens/dipeptides/PE.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 32 bonds>
# Time: 0.72011 s
#
# add_Hydrogens/dipeptides/PF.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 38 bonds>
# Time: 0.71919 s
#
# add_Hydrogens/dipeptides/PG.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 24 bonds>
# Time: 0.72975 s
#
# add_Hydrogens/dipeptides/PH.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 35 bonds>
# Time: 0.71486 s
#
# add_Hydrogens/dipeptides/PI.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 36 bonds>
# Time: 0.71301 s
#
# add_Hydrogens/dipeptides/PK.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 0.72022 s
#
# add_Hydrogens/dipeptides/PL.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 36 bonds>
# Time: 0.73136 s
#
# add_Hydrogens/dipeptides/PM.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.75299 s
#
# add_Hydrogens/dipeptides/PN.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 0.72075 s
#
# add_Hydrogens/dipeptides/PP.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 32 bonds>
# Time: 1.12506 s
#
# add_Hydrogens/dipeptides/PQ.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.81391 s
#
# add_Hydrogens/dipeptides/PR.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 41 bonds>
# Time: 1.10695 s
#
# add_Hydrogens/dipeptides/PS.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 28 bonds>
# Time: 0.66084 s
#
# add_Hydrogens/dipeptides/PT.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 1.08987 s
#
# add_Hydrogens/dipeptides/PV.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 33 bonds>
# Time: 1.09060 s
#
# add_Hydrogens/dipeptides/PW.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 43 bonds>
# Time: 1.09326 s
#
# add_Hydrogens/dipeptides/PY.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 39 bonds>
# Time: 1.09547 s
#
# add_Hydrogens/dipeptides/QA.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 0.28596 s
#
# add_Hydrogens/dipeptides/QC.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.28590 s
#
# add_Hydrogens/dipeptides/QD.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.28580 s
#
# add_Hydrogens/dipeptides/QE.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 34 bonds>
# Time: 0.28141 s
#
# add_Hydrogens/dipeptides/QF.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 40 bonds>
# Time: 0.28059 s
#
# add_Hydrogens/dipeptides/QG.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 26 bonds>
# Time: 0.28346 s
#
# add_Hydrogens/dipeptides/QH.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 37 bonds>
# Time: 0.28678 s
#
# add_Hydrogens/dipeptides/QI.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.28098 s
#
# add_Hydrogens/dipeptides/QK.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 41 bonds>
# Time: 0.29178 s
#
# add_Hydrogens/dipeptides/QL.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.28448 s
#
# add_Hydrogens/dipeptides/QM.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 0.28715 s
#
# add_Hydrogens/dipeptides/QN.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.28971 s
#
# add_Hydrogens/dipeptides/QP.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.73444 s
#
# add_Hydrogens/dipeptides/QQ.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 0.77979 s
#
# add_Hydrogens/dipeptides/QR.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 43 bonds>
# Time: 0.78661 s
#
# add_Hydrogens/dipeptides/QS.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.29929 s
#
# add_Hydrogens/dipeptides/QT.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.78602 s
#
# add_Hydrogens/dipeptides/QV.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.71649 s
#
# add_Hydrogens/dipeptides/QW.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 45 bonds>
# Time: 0.78564 s
#
# add_Hydrogens/dipeptides/QY.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 41 bonds>
# Time: 0.78464 s
#
# add_Hydrogens/dipeptides/RA.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 36 bonds>
# Time: 0.29824 s
#
# add_Hydrogens/dipeptides/RC.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 37 bonds>
# Time: 0.29174 s
#
# add_Hydrogens/dipeptides/RD.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.28855 s
#
# add_Hydrogens/dipeptides/RE.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 41 bonds>
# Time: 0.30903 s
#
# add_Hydrogens/dipeptides/RF.pdb
# <Topology; 1 chains, 2 residues, 47 atoms, 47 bonds>
# Time: 0.30128 s
#
# add_Hydrogens/dipeptides/RG.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.30277 s
#
# add_Hydrogens/dipeptides/RH.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 44 bonds>
# Time: 0.29476 s
#
# add_Hydrogens/dipeptides/RI.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 45 bonds>
# Time: 0.30243 s
#
# add_Hydrogens/dipeptides/RK.pdb
# <Topology; 1 chains, 2 residues, 49 atoms, 48 bonds>
# Time: 0.29218 s
#
# add_Hydrogens/dipeptides/RL.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 45 bonds>
# Time: 0.29131 s
#
# add_Hydrogens/dipeptides/RM.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 43 bonds>
# Time: 0.29864 s
#
# add_Hydrogens/dipeptides/RN.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 0.29055 s
#
# add_Hydrogens/dipeptides/RP.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 41 bonds>
# Time: 0.71423 s
#
# add_Hydrogens/dipeptides/RQ.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 43 bonds>
# Time: 0.28868 s
#
# add_Hydrogens/dipeptides/RR.pdb
# <Topology; 1 chains, 2 residues, 51 atoms, 50 bonds>
# Time: 1.09039 s
#
# add_Hydrogens/dipeptides/RS.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 37 bonds>
# Time: 0.65517 s
#
# add_Hydrogens/dipeptides/RT.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 1.10261 s
#
# add_Hydrogens/dipeptides/RV.pdb
# <Topology; 1 chains, 2 residues, 43 atoms, 42 bonds>
# Time: 1.09106 s
#
# add_Hydrogens/dipeptides/RW.pdb
# <Topology; 1 chains, 2 residues, 51 atoms, 52 bonds>
# Time: 1.09756 s
#
# add_Hydrogens/dipeptides/RY.pdb
# <Topology; 1 chains, 2 residues, 48 atoms, 48 bonds>
# Time: 1.12179 s
#
# add_Hydrogens/dipeptides/SA.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 23 bonds>
# Time: 0.28637 s
#
# add_Hydrogens/dipeptides/SC.pdb
# <Topology; 1 chains, 2 residues, 25 atoms, 24 bonds>
# Time: 0.28211 s
#
# add_Hydrogens/dipeptides/SD.pdb
# <Topology; 1 chains, 2 residues, 26 atoms, 25 bonds>
# Time: 0.28470 s
#
# add_Hydrogens/dipeptides/SE.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.29832 s
#
# add_Hydrogens/dipeptides/SF.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.28132 s
#
# add_Hydrogens/dipeptides/SG.pdb
# <Topology; 1 chains, 2 residues, 21 atoms, 20 bonds>
# Time: 0.31603 s
#
# add_Hydrogens/dipeptides/SH.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 0.30383 s
#
# add_Hydrogens/dipeptides/SI.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.29255 s
#
# add_Hydrogens/dipeptides/SK.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.30097 s
#
# add_Hydrogens/dipeptides/SL.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.29652 s
#
# add_Hydrogens/dipeptides/SM.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.30330 s
#
# add_Hydrogens/dipeptides/SN.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 0.30278 s
#
# add_Hydrogens/dipeptides/SP.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 28 bonds>
# Time: 0.29814 s
#
# add_Hydrogens/dipeptides/SQ.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.29498 s
#
# add_Hydrogens/dipeptides/SR.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 37 bonds>
# Time: 0.31581 s
#
# add_Hydrogens/dipeptides/SS.pdb
# <Topology; 1 chains, 2 residues, 25 atoms, 24 bonds>
# Time: 0.68199 s
#
# add_Hydrogens/dipeptides/ST.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 0.66800 s
#
# add_Hydrogens/dipeptides/SV.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 0.66524 s
#
# add_Hydrogens/dipeptides/SW.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 39 bonds>
# Time: 0.67251 s
#
# add_Hydrogens/dipeptides/SY.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 35 bonds>
# Time: 0.66513 s
#
# add_Hydrogens/dipeptides/TA.pdb
# <Topology; 1 chains, 2 residues, 27 atoms, 26 bonds>
# Time: 0.28835 s
#
# add_Hydrogens/dipeptides/TC.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 0.29229 s
#
# add_Hydrogens/dipeptides/TD.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.28747 s
#
# add_Hydrogens/dipeptides/TE.pdb
# <Topology; 1 chains, 2 residues, 32 atoms, 31 bonds>
# Time: 0.30278 s
#
# add_Hydrogens/dipeptides/TF.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 37 bonds>
# Time: 0.32354 s
#
# add_Hydrogens/dipeptides/TG.pdb
# <Topology; 1 chains, 2 residues, 24 atoms, 23 bonds>
# Time: 0.28272 s
#
# add_Hydrogens/dipeptides/TH.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.29678 s
#
# add_Hydrogens/dipeptides/TI.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.28532 s
#
# add_Hydrogens/dipeptides/TK.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 38 bonds>
# Time: 0.29209 s
#
# add_Hydrogens/dipeptides/TL.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.28803 s
#
# add_Hydrogens/dipeptides/TM.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.31713 s
#
# add_Hydrogens/dipeptides/TN.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.28204 s
#
# add_Hydrogens/dipeptides/TP.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 0.73172 s
#
# add_Hydrogens/dipeptides/TQ.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.28013 s
#
# add_Hydrogens/dipeptides/TR.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 0.28177 s
#
# add_Hydrogens/dipeptides/TS.pdb
# <Topology; 1 chains, 2 residues, 28 atoms, 27 bonds>
# Time: 0.28305 s
#
# add_Hydrogens/dipeptides/TT.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 1.10045 s
#
# add_Hydrogens/dipeptides/TV.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.71538 s
#
# add_Hydrogens/dipeptides/TW.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 42 bonds>
# Time: 1.12275 s
#
# add_Hydrogens/dipeptides/TY.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 38 bonds>
# Time: 1.10283 s
#
# add_Hydrogens/dipeptides/VA.pdb
# <Topology; 1 chains, 2 residues, 29 atoms, 28 bonds>
# Time: 0.29822 s
#
# add_Hydrogens/dipeptides/VC.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 0.29866 s
#
# add_Hydrogens/dipeptides/VD.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 30 bonds>
# Time: 0.30418 s
#
# add_Hydrogens/dipeptides/VE.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 33 bonds>
# Time: 0.29583 s
#
# add_Hydrogens/dipeptides/VF.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 0.29530 s
#
# add_Hydrogens/dipeptides/VG.pdb
# <Topology; 1 chains, 2 residues, 26 atoms, 25 bonds>
# Time: 0.30023 s
#
# add_Hydrogens/dipeptides/VH.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 36 bonds>
# Time: 0.30000 s
#
# add_Hydrogens/dipeptides/VI.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 37 bonds>
# Time: 0.29566 s
#
# add_Hydrogens/dipeptides/VK.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 40 bonds>
# Time: 0.29309 s
#
# add_Hydrogens/dipeptides/VL.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 37 bonds>
# Time: 0.29281 s
#
# add_Hydrogens/dipeptides/VM.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.29727 s
#
# add_Hydrogens/dipeptides/VN.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.32238 s
#
# add_Hydrogens/dipeptides/VP.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 33 bonds>
# Time: 0.71993 s
#
# add_Hydrogens/dipeptides/VQ.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 35 bonds>
# Time: 0.28776 s
#
# add_Hydrogens/dipeptides/VR.pdb
# <Topology; 1 chains, 2 residues, 43 atoms, 42 bonds>
# Time: 0.28981 s
#
# add_Hydrogens/dipeptides/VS.pdb
# <Topology; 1 chains, 2 residues, 30 atoms, 29 bonds>
# Time: 0.29324 s
#
# add_Hydrogens/dipeptides/VT.pdb
# <Topology; 1 chains, 2 residues, 33 atoms, 32 bonds>
# Time: 0.29409 s
#
# add_Hydrogens/dipeptides/VV.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 34 bonds>
# Time: 1.09846 s
#
# add_Hydrogens/dipeptides/VW.pdb
# <Topology; 1 chains, 2 residues, 43 atoms, 44 bonds>
# Time: 1.09382 s
#
# add_Hydrogens/dipeptides/VY.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 40 bonds>
# Time: 1.09282 s
#
# add_Hydrogens/dipeptides/WA.pdb
# <Topology; 1 chains, 2 residues, 37 atoms, 38 bonds>
# Time: 0.28404 s
#
# add_Hydrogens/dipeptides/WC.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 39 bonds>
# Time: 0.28420 s
#
# add_Hydrogens/dipeptides/WD.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 40 bonds>
# Time: 0.29146 s
#
# add_Hydrogens/dipeptides/WE.pdb
# <Topology; 1 chains, 2 residues, 42 atoms, 43 bonds>
# Time: 0.28609 s
#
# add_Hydrogens/dipeptides/WF.pdb
# <Topology; 1 chains, 2 residues, 47 atoms, 49 bonds>
# Time: 0.28466 s
#
# add_Hydrogens/dipeptides/WG.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 35 bonds>
# Time: 0.28043 s
#
# add_Hydrogens/dipeptides/WH.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 46 bonds>
# Time: 0.29070 s
#
# add_Hydrogens/dipeptides/WI.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 47 bonds>
# Time: 0.29085 s
#
# add_Hydrogens/dipeptides/WK.pdb
# <Topology; 1 chains, 2 residues, 49 atoms, 50 bonds>
# Time: 0.28658 s
#
# add_Hydrogens/dipeptides/WL.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 47 bonds>
# Time: 0.29094 s
#
# add_Hydrogens/dipeptides/WM.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 45 bonds>
# Time: 0.28188 s
#
# add_Hydrogens/dipeptides/WN.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 42 bonds>
# Time: 0.32327 s
#
# add_Hydrogens/dipeptides/WP.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 43 bonds>
# Time: 0.72547 s
#
# add_Hydrogens/dipeptides/WQ.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 45 bonds>
# Time: 0.29422 s
#
# add_Hydrogens/dipeptides/WR.pdb
# <Topology; 1 chains, 2 residues, 51 atoms, 52 bonds>
# Time: 0.29363 s
#
# add_Hydrogens/dipeptides/WS.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 39 bonds>
# Time: 0.29942 s
#
# add_Hydrogens/dipeptides/WT.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 42 bonds>
# Time: 0.29041 s
#
# add_Hydrogens/dipeptides/WV.pdb
# <Topology; 1 chains, 2 residues, 43 atoms, 44 bonds>
# Time: 0.29458 s
#
# add_Hydrogens/dipeptides/WW.pdb
# <Topology; 1 chains, 2 residues, 51 atoms, 54 bonds>
# Time: 1.10602 s
#
# add_Hydrogens/dipeptides/WY.pdb
# <Topology; 1 chains, 2 residues, 48 atoms, 50 bonds>
# Time: 1.10364 s
#
# add_Hydrogens/dipeptides/YA.pdb
# <Topology; 1 chains, 2 residues, 34 atoms, 34 bonds>
# Time: 0.29693 s
#
# add_Hydrogens/dipeptides/YC.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 35 bonds>
# Time: 0.29750 s
#
# add_Hydrogens/dipeptides/YD.pdb
# <Topology; 1 chains, 2 residues, 36 atoms, 36 bonds>
# Time: 0.29783 s
#
# add_Hydrogens/dipeptides/YE.pdb
# <Topology; 1 chains, 2 residues, 39 atoms, 39 bonds>
# Time: 0.31628 s
#
# add_Hydrogens/dipeptides/YF.pdb
# <Topology; 1 chains, 2 residues, 44 atoms, 45 bonds>
# Time: 0.29658 s
#
# add_Hydrogens/dipeptides/YG.pdb
# <Topology; 1 chains, 2 residues, 31 atoms, 31 bonds>
# Time: 0.28708 s
#
# add_Hydrogens/dipeptides/YH.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 42 bonds>
# Time: 0.29277 s
#
# add_Hydrogens/dipeptides/YI.pdb
# <Topology; 1 chains, 2 residues, 43 atoms, 43 bonds>
# Time: 0.28712 s
#
# add_Hydrogens/dipeptides/YK.pdb
# <Topology; 1 chains, 2 residues, 46 atoms, 46 bonds>
# Time: 0.29104 s
#
# add_Hydrogens/dipeptides/YL.pdb
# <Topology; 1 chains, 2 residues, 43 atoms, 43 bonds>
# Time: 0.28751 s
#
# add_Hydrogens/dipeptides/YM.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 41 bonds>
# Time: 0.29279 s
#
# add_Hydrogens/dipeptides/YN.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 38 bonds>
# Time: 0.30370 s
#
# add_Hydrogens/dipeptides/YP.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 39 bonds>
# Time: 0.71779 s
#
# add_Hydrogens/dipeptides/YQ.pdb
# <Topology; 1 chains, 2 residues, 41 atoms, 41 bonds>
# Time: 0.28516 s
#
# add_Hydrogens/dipeptides/YR.pdb
# <Topology; 1 chains, 2 residues, 48 atoms, 48 bonds>
# Time: 0.29058 s
#
# add_Hydrogens/dipeptides/YS.pdb
# <Topology; 1 chains, 2 residues, 35 atoms, 35 bonds>
# Time: 0.28516 s
#
# add_Hydrogens/dipeptides/YT.pdb
# <Topology; 1 chains, 2 residues, 38 atoms, 38 bonds>
# Time: 0.28332 s
#
# add_Hydrogens/dipeptides/YV.pdb
# <Topology; 1 chains, 2 residues, 40 atoms, 40 bonds>
# Time: 0.28777 s
#
# add_Hydrogens/dipeptides/YW.pdb
# <Topology; 1 chains, 2 residues, 48 atoms, 50 bonds>
# Time: 0.27889 s
#
# add_Hydrogens/dipeptides/YY.pdb
# <Topology; 1 chains, 2 residues, 45 atoms, 46 bonds>
# Time: 1.10076 s
